# %%
# !pip install yfinance
# !pip install bs4
# !pip install nbformat
# Out:
# Collecting yfinance
# WARNING: Ignoring invalid distribution ~ertifi (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~olars (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
#   DEPRECATION: Building 'multitasking' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'multitasking'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# WARNING: Ignoring invalid distribution ~ertifi (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~olars (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ertifi (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~olars (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
#   Downloading yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\kiit0001\anaconda3\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: requests>=2.31 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\kiit0001\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\kiit0001\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.3.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      ------ --------------------------------- 0.5/3.0 MB 964.4 kB/s eta 0:00:03
#      ---------- ----------------------------- 0.8/3.0 MB 1.1 MB/s eta 0:00:03
#      ---------- ----------------------------- 0.8/3.0 MB 1.1 MB/s eta 0:00:03
#      ------------- -------------------------- 1.0/3.0 MB 913.8 kB/s eta 0:00:03
#      ----------------- ---------------------- 1.3/3.0 MB 887.7 kB/s eta 0:00:02
#      ----------------- ---------------------- 1.3/3.0 MB 887.7 kB/s eta 0:00:02
#      -------------------- ------------------- 1.6/3.0 MB 856.2 kB/s eta 0:00:02
#      -------------------- ------------------- 1.6/3.0 MB 856.2 kB/s eta 0:00:02
#      -------------------- ------------------- 1.6/3.0 MB 856.2 kB/s eta 0:00:02
#      -------------------- ------------------- 1.6/3.0 MB 856.2 kB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 645.0 kB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 645.0 kB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 644.6 kB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 644.6 kB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 644.6 kB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 644.6 kB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 644.6 kB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 644.6 kB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 644.6 kB/s eta 0:00:02
#      --------------------------- ------------ 2.1/3.0 MB 644.6 kB/s eta 0:00:02
#      ------------------------------- -------- 2.4/3.0 MB 458.1 kB/s eta 0:00:02
#      ------------------------------- -------- 2.4/3.0 MB 458.1 kB/s eta 0:00:02
#      ------------------------------- -------- 2.4/3.0 MB 458.1 kB/s eta 0:00:02
#      ------------------------------- -------- 2.4/3.0 MB 458.1 kB/s eta 0:00:02
#      ------------------------------- -------- 2.4/3.0 MB 458.1 kB/s eta 0:00:02
#      ------------------------------- -------- 2.4/3.0 MB 458.1 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 403.8 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 403.8 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 403.8 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 403.8 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 403.8 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 403.8 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 403.8 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 403.8 kB/s eta 0:00:02
#      -------------------------------------- - 2.9/3.0 MB 350.3 kB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 350.3 kB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 350.3 kB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 350.3 kB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 350.3 kB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 350.3 kB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 313.3 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\kiit0001\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.14.0-cp39-abi3-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from yfinance) (6.33.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kiit0001\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\kiit0001\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: pycparser in c:\users\kiit0001\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kiit0001\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kiit0001\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\kiit0001\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kiit0001\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit0001\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kiit0001\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Downloading yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Downloading curl_cffi-0.14.0-cp39-abi3-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------ --------------------------- 0.5/1.7 MB 172.1 kB/s eta 0:00:07
#    ------------------ --------------------- 0.8/1.7 MB 116.0 kB/s eta 0:00:08
#    ------------------ --------------------- 0.8/1.7 MB 116.0 kB/s eta 0:00:08
#    ------------------ --------------------- 0.8/1.7 MB 116.0 kB/s eta 0:00:08
#    ------------------ --------------------- 0.8/1.7 MB 116.0 kB/s eta 0:00:08
#    ------------------ --------------------- 0.8/1.7 MB 116.0 kB/s eta 0:00:08
#    ------------------ --------------------- 0.8/1.7 MB 116.0 kB/s eta 0:00:08
#    ------------------ --------------------- 0.8/1.7 MB 116.0 kB/s eta 0:00:08
#    ------------------ --------------------- 0.8/1.7 MB 116.0 kB/s eta 0:00:08
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------- -------------- 1.0/1.7 MB 125.8 kB/s eta 0:00:06
#    ------------------------------- -------- 1.3/1.7 MB 121.4 kB/s eta 0:00:04
#    ------------------------------- -------- 1.3/1.7 MB 121.4 kB/s eta 0:00:04
#    ------------------------------- -------- 1.3/1.7 MB 121.4 kB/s eta 0:00:04
#    ------------------------------- -------- 1.3/1.7 MB 121.4 kB/s eta 0:00:04
#    ------------------------------- -------- 1.3/1.7 MB 121.4 kB/s eta 0:00:04
#    ------------------------------- -------- 1.3/1.7 MB 121.4 kB/s eta 0:00:04
#    ------------------------------- -------- 1.3/1.7 MB 121.4 kB/s eta 0:00:04
#    ------------------------------- -------- 1.3/1.7 MB 121.4 kB/s eta 0:00:04
#    ------------------------------- -------- 1.3/1.7 MB 121.4 kB/s eta 0:00:04
#    ------------------------------------- -- 1.6/1.7 MB 124.1 kB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 124.1 kB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 124.1 kB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 124.1 kB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 123.7 kB/s eta 0:00:00
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=030077c0df72c0ea82097c469cfc19060c9f21b4bd3e0f8cad54deb26b783c50
#   Stored in directory: c:\users\kiit0001\appdata\local\pip\cache\wheels\1e\df\0f\e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.3-py3-none-any.whl size=139181 sha256=bbbbd5e81b15722665e6071c781d0ad013ad6748ebddea3f99b4a6632af28a6b
#   Stored in directory: c:\users\kiit0001\appdata\local\pip\cache\wheels\8c\a9\a4\df972cd49f865ffde174d9c5b26f14f08f8a363ed31e10ff91
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, curl_cffi, yfinance
#
#    ---------------------------------------- 0/4 [peewee]
#    ---------------------------------------- 0/4 [peewee]
#    ---------------------------------------- 0/4 [peewee]
#    ---------------------------------------- 0/4 [peewee]
#    -------------------- ------------------- 2/4 [curl_cffi]
#    -------------------- ------------------- 2/4 [curl_cffi]
#    ------------------------------ --------- 3/4 [yfinance]
#    ------------------------------ --------- 3/4 [yfinance]
#    ------------------------------ --------- 3/4 [yfinance]
#    ------------------------------ --------- 3/4 [yfinance]
#    ---------------------------------------- 4/4 [yfinance]
#
# Successfully installed curl_cffi-0.14.0 multitasking-0.0.12 peewee-3.18.3 yfinance-0.2.66
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\kiit0001\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kiit0001\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# WARNING: Ignoring invalid distribution ~ertifi (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~olars (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ertifi (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~olars (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ertifi (C:\Users\KIIT0001\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~olars (C:\Users\KIIT0001\anaconda3\Lib\site-packages)

# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
import plotly.graph_objects as go

# %%
tesla = yf.Ticker("TSLA")
tesla_stock_data = tesla.history(period="max")
tesla_stock_data.reset_index(inplace=True)

tesla_stock_data.head()

# %%
url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")

tesla_revenue = pd.DataFrame(columns=["Date", "Revenue"])

for row in soup.find_all("tbody")[1].find_all("tr"):
    cols = row.find_all("td")
    date = cols[0].text
    revenue = cols[1].text.replace("$", "").replace(",", "")
    tesla_revenue = pd.concat(
        [tesla_revenue, pd.DataFrame({"Date":[date], "Revenue":[revenue]})],
        ignore_index=True
    )

tesla_revenue.head()

# %%
gamestop = yf.Ticker("GME")
gme_stock_data = gamestop.history(period="max")
gme_stock_data.reset_index(inplace=True)

gme_stock_data.head()

# %%
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")

gme_revenue = pd.DataFrame(columns=["Date", "Revenue"])

for row in soup.find_all("tbody")[1].find_all("tr"):
    cols = row.find_all("td")
    date = cols[0].text
    revenue = cols[1].text.replace("$", "").replace(",", "")
    gme_revenue = pd.concat(
        [gme_revenue, pd.DataFrame({"Date":[date], "Revenue":[revenue]})],
        ignore_index=True
    )

gme_revenue.head()
